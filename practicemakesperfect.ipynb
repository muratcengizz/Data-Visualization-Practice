# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
dataset = sns.load_dataset('anagrams')
df = dataset.copy()
df.head()
# Out:
#    subidr    attnr  num1  num2  num3
# 0       1  divided     2   4.0     7
# 1       2  divided     3   4.0     5
# 2       3  divided     3   5.0     6
# 3       4  divided     5   7.0     5
# 4       5  divided     4   5.0     8

# %%
df.describe().T
# Out:
#         count    mean       std  min   25%   50%    75%   max
# subidr   20.0  10.500  5.916080  1.0  5.75  10.5  15.25  20.0
# num1     20.0   5.350  1.843195  2.0  4.75   5.5   6.25   8.0
# num2     20.0   5.975  1.673910  3.0  5.00   5.5   7.25   9.0
# num3     20.0   6.550  1.099043  5.0  6.00   6.0   7.00   9.0

# %%
df.columns
# Out:
# Index(['subidr', 'attnr', 'num1', 'num2', 'num3'], dtype='object')

# %%
df.tail()
# Out:
#     subidr    attnr  num1  num2  num3
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
df.size
# Out:
# 100

# %%
df.shape
# Out:
# (20, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   subidr  20 non-null     int64
#  1   attnr   20 non-null     object
#  2   num1    20 non-null     int64
#  3   num2    20 non-null     float64
#  4   num3    20 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 928.0+ bytes

# %%
df.attnr.unique()
# Out:
# array(['divided', 'focused'], dtype=object)

# %%
df.groupby('attnr')['num1'].sum()
# Out:
# attnr
# divided    40
# focused    67
# Name: num1, dtype: int64

# %%
df.groupby('attnr')[['num1', 'num2']].mean()
# Out:
#          num1  num2
# attnr
# divided   4.0  4.95
# focused   6.7  7.00

# %%
df.head()
# Out:
#    subidr    attnr  num1  num2  num3
# 0       1  divided     2   4.0     7
# 1       2  divided     3   4.0     5
# 2       3  divided     3   5.0     6
# 3       4  divided     5   7.0     5
# 4       5  divided     4   5.0     8

# %%
df.groupby('attnr')[['num1', 'num2', 'num3']].describe().T
# Out:
# attnr         divided    focused
# num1 count  10.000000  10.000000
#      mean    4.000000   6.700000
#      std     1.414214   1.059350
#      min     2.000000   5.000000
#      25%     3.000000   6.000000
#      50%     4.500000   6.500000
#      75%     5.000000   7.750000
#      max     6.000000   8.000000
# num2 count  10.000000  10.000000
#      mean    4.950000   7.000000
#      std     1.257201   1.414214
#      min     3.000000   5.000000
#      25%     4.125000   6.000000
#      50%     5.000000   7.500000
#      75%     5.000000   8.000000
#      max     7.000000   9.000000
# num3 count  10.000000  10.000000
#      mean    6.400000   6.700000
#      std     1.074968   1.159502
#      min     5.000000   5.000000
#      25%     6.000000   6.000000
#      50%     6.000000   6.500000
#      75%     7.000000   7.000000
#      max     8.000000   9.000000

# %%
# ?sns.load_dataset
# Out:
# Signature: sns.load_dataset(name, cache=True, data_home=None, **kws)
# Docstring:
# Load an example dataset from the online repository (requires internet).
#
# This function provides quick access to a small number of example datasets
# that are useful for documenting seaborn or generating reproducible examples
# for bug reports. It is not necessary for normal usage.
#
# Note that some of the datasets have a small amount of preprocessing applied
# to define a proper ordering for categorical variables.
#
# Use :func:`get_dataset_names` to see a list of available datasets.
#
# Parameters
# ----------
# name : str
#     Name of the dataset (``{name}.csv`` on
#     https://github.com/mwaskom/seaborn-data).
# cache : boolean, optional
#     If True, try to load from the local cache first, and save to the cache
#     if a download is required.
# data_home : string, optional
#     The directory in which to cache data; see :func:`get_data_home`.
# kws : keys and values, optional
# ...

# %%
df
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
df.groupby('attnr')[['num1']].aggregate('max')
# Out:
#          num1
# attnr
# divided     6
# focused     8

# %%
df.groupby('attnr')[['num1', 'num2']].aggregate('max', 'min').T
# Out:
# attnr  divided  focused
# num1       6.0      8.0
# num2       7.0      9.0

# %%
def func(x):
    return x['num1'].sum() > 9

df.groupby('attnr').filter(func)
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
def func(*args):
    print(*args)
df.groupby('attnr').filter(func)
# Out:
#    subidr    attnr  num1  num2  num3
# 0       1  divided     2   4.0     7
# 1       2  divided     3   4.0     5
# 2       3  divided     3   5.0     6
# 3       4  divided     5   7.0     5
# 4       5  divided     4   5.0     8
# 5       6  divided     5   5.0     6
# 6       7  divided     5   4.5     6
# 7       8  divided     5   7.0     8
# 8       9  divided     2   3.0     7
# 9      10  divided     6   5.0     6
#     subidr    attnr  num1  num2  num3
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5
# Empty DataFrame
# Columns: [subidr, attnr, num1, num2, num3]
# Index: []

# %%
def func(x):
    if x['num1'].sum() > 5:
        print('Hello World!')
df.groupby('attnr').filter(func)
# Out:
# Hello World!
# Hello World!
# Empty DataFrame
# Columns: [subidr, attnr, num1, num2, num3]
# Index: []

# %%
def func(x):
    return x['num1'].iloc[0] < 5

df.groupby('attnr').filter(func)
# Out:
#    subidr    attnr  num1  num2  num3
# 0       1  divided     2   4.0     7
# 1       2  divided     3   4.0     5
# 2       3  divided     3   5.0     6
# 3       4  divided     5   7.0     5
# 4       5  divided     4   5.0     8
# 5       6  divided     5   5.0     6
# 6       7  divided     5   4.5     6
# 7       8  divided     5   7.0     8
# 8       9  divided     2   3.0     7
# 9      10  divided     6   5.0     6

# %%
def func(x):
    if x['num1'].iloc[1] > 5:
        return True
    else:
        return False
df.groupby('attnr').filter(func)
# Out:
#     subidr    attnr  num1  num2  num3
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
df.groupby('attnr').transform(lambda x: x+1)
# Out:
#     subidr  num1  num2  num3
# 0        2     3   5.0     8
# 1        3     4   5.0     6
# 2        4     4   6.0     7
# 3        5     6   8.0     6
# 4        6     5   6.0     9
# 5        7     6   6.0     7
# 6        8     6   5.5     7
# 7        9     6   8.0     9
# 8       10     3   4.0     8
# 9       11     7   6.0     7
# 10      12     7   6.0     7
# 11      13     9  10.0     9
# 12      14     7   6.0    10
# 13      15     9   9.0     8
# 14      16     9   9.0     8
# 15      17     7   9.0     8
# 16      18     8   8.0     7
# 17      19     8   9.0     7
# 18      20     6   7.0     7
# 19      21     7   7.0     6

# %%
def func(x):
    return x+1
df.groupby('attnr').transform(func)
# Out:
#     subidr  num1  num2  num3
# 0        2     3   5.0     8
# 1        3     4   5.0     6
# 2        4     4   6.0     7
# 3        5     6   8.0     6
# 4        6     5   6.0     9
# 5        7     6   6.0     7
# 6        8     6   5.5     7
# 7        9     6   8.0     9
# 8       10     3   4.0     8
# 9       11     7   6.0     7
# 10      12     7   6.0     7
# 11      13     9  10.0     9
# 12      14     7   6.0    10
# 13      15     9   9.0     8
# 14      16     9   9.0     8
# 15      17     7   9.0     8
# 16      18     8   8.0     7
# 17      19     8   9.0     7
# 18      20     6   7.0     7
# 19      21     7   7.0     6

# %%
def func(x):
    return x + 1

df.groupby('attnr').transform(func).head()
# Out:
#    subidr  num1  num2  num3
# 0       2     3   5.0     8
# 1       3     4   5.0     6
# 2       4     4   6.0     7
# 3       5     6   8.0     6
# 4       6     5   6.0     9

# %%
df.groupby('attnr')[['num1']].transform('sum').head()
# Out:
#    num1
# 0    40
# 1    40
# 2    40
# 3    40
# 4    40

# %%
def func(x):
    return x + 1
df.groupby('attnr')['num1'].transform(func)
# Out:
# 0     3
# 1     4
# 2     4
# 3     6
# 4     5
# 5     6
# 6     6
# 7     6
# 8     3
# 9     7
# 10    7
# 11    9
# 12    7
# 13    9
# 14    9
# 15    7
# 16    8
# 17    8
# 18    6
# 19    7
# Name: num1, dtype: int64

# %%
def func(x):
    return x * 0
df.groupby('attnr')['num1'].transform(func).head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: num1, dtype: int64

# %%
def func(x):
    return x.iloc[0]
df.groupby('attnr')['num1'].transform(func).head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: num1, dtype: int64

# %%
def func(x):
    return x + 1

df.groupby('attnr')[['num2']].transform(func).tail(3)
# Out:
#     num2
# 17   9.0
# 18   7.0
# 19   7.0

# %%
def func(x):
    return x.sum() > 10

df.groupby('attnr')['num1'].filter(func).head()
# Out:
# 0    2
# 1    3
# 2    3
# 3    5
# 4    4
# Name: num1, dtype: int64

# %%
def func(x):
    if x.sum() > 10:
        return True

df.groupby('attnr')['num1'].transform(func).head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: num1, dtype: bool

# %%
def func(x):
    if x.sum() > 10:
        return True
    
df.groupby('attnr')['num1'].filter(func).head()
# Out:
# 0    2
# 1    3
# 2    3
# 3    5
# 4    4
# Name: num1, dtype: int64

# %%
def func(x):
    sayac = 0
    for element in x:
        print(f'{sayac}.index + {element}')
        sayac += 1
func(df['num1'])
# Out:
# 0.index + 2
# 1.index + 3
# 2.index + 3
# 3.index + 5
# 4.index + 4
# 5.index + 5
# 6.index + 5
# 7.index + 5
# 8.index + 2
# 9.index + 6
# 10.index + 6
# 11.index + 8
# 12.index + 6
# 13.index + 8
# 14.index + 8
# 15.index + 6
# 16.index + 7
# 17.index + 7
# 18.index + 5
# 19.index + 6

# %%
def func(x):
    sayac = 0
    for element in x:
        print(pow(element, 2))
        sayac += 1
        if element == x.iloc[-1]:
            print(f'sayac: {sayac:.0f}')
func(df['num2'])
# Out:
# 16.0
# 16.0
# 25.0
# 49.0
# 25.0
# 25.0
# 20.25
# 49.0
# 9.0
# 25.0
# 25.0
# 81.0
# 25.0
# 64.0
# 64.0
# 64.0
# 49.0
# 64.0
# 36.0
# sayac: 19
# 36.0
# sayac: 20

# %%
df.head()
# Out:
#    subidr    attnr  num1  num2  num3
# 0       1  divided     2   4.0     7
# 1       2  divided     3   4.0     5
# 2       3  divided     3   5.0     6
# 3       4  divided     5   7.0     5
# 4       5  divided     4   5.0     8

# %%
df.groupby('attnr')[['num1', 'num2', 'num3']].describe().T
# Out:
# attnr         divided    focused
# num1 count  10.000000  10.000000
#      mean    4.000000   6.700000
#      std     1.414214   1.059350
#      min     2.000000   5.000000
#      25%     3.000000   6.000000
#      50%     4.500000   6.500000
#      75%     5.000000   7.750000
#      max     6.000000   8.000000
# num2 count  10.000000  10.000000
#      mean    4.950000   7.000000
#      std     1.257201   1.414214
#      min     3.000000   5.000000
#      25%     4.125000   6.000000
#      50%     5.000000   7.500000
#      75%     5.000000   8.000000
#      max     7.000000   9.000000
# num3 count  10.000000  10.000000
#      mean    6.400000   6.700000
#      std     1.074968   1.159502
#      min     5.000000   5.000000
#      25%     6.000000   6.000000
#      50%     6.000000   6.500000
#      75%     7.000000   7.000000
#      max     8.000000   9.000000

# %%
df
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
kat_df = df.select_dtypes(include=['object'])
kat_df.head()
# Out:
#      attnr
# 0  divided
# 1  divided
# 2  divided
# 3  divided
# 4  divided

# %%
kat_df.tail()
# Out:
#       attnr
# 15  focused
# 16  focused
# 17  focused
# 18  focused
# 19  focused

# %%
kat_df.attnr.unique()
# Out:
# array(['divided', 'focused'], dtype=object)

# %%
kat_df['attnr'].value_counts().count()
# Out:
# 2

# %%
kat_df['attnr'].value_counts()
# Out:
# divided    10
# focused    10
# Name: attnr, dtype: int64

# %%
df['attnr'].value_counts().plot.barh();

# %%
#------------------------------------------------------------------------------------------------------------

# %%
# ?sns.get_dataset_names
# Out:
# Signature: sns.get_dataset_names()
# Docstring:
# Report available example datasets, useful for reporting issues.
#
# Requires an internet connection.
# File:      c:\users\murat\anaconda3\lib\site-packages\seaborn\utils.py
# Type:      function

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('anscombe')
df = df.copy()

# %%
df.describe().T
# Out:
#    count      mean       std  min     25%   50%      75%    max
# x   44.0  9.000000  3.198837  4.0  7.0000  8.00  11.0000  19.00
# y   44.0  7.500682  1.958925  3.1  6.1175  7.52   8.7475  12.74

# %%
df.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
df.columns
# Out:
# Index(['dataset', 'x', 'y'], dtype='object')

# %%
df.groupby('dataset')[['x', 'y']].describe().T
# Out:
# dataset          I         II        III         IV
# x count  11.000000  11.000000  11.000000  11.000000
#   mean    9.000000   9.000000   9.000000   9.000000
#   std     3.316625   3.316625   3.316625   3.316625
#   min     4.000000   4.000000   4.000000   8.000000
#   25%     6.500000   6.500000   6.500000   8.000000
#   50%     9.000000   9.000000   9.000000   8.000000
#   75%    11.500000  11.500000  11.500000   8.000000
#   max    14.000000  14.000000  14.000000  19.000000
# y count  11.000000  11.000000  11.000000  11.000000
#   mean    7.500909   7.500909   7.500000   7.500909
#   std     2.031568   2.031657   2.030424   2.030579
#   min     4.260000   3.100000   5.390000   5.250000
#   25%     6.315000   6.695000   6.250000   6.170000
#   50%     7.580000   8.140000   7.110000   7.040000
#   75%     8.570000   8.950000   7.980000   8.190000
#   max    10.840000   9.260000  12.740000  12.500000

# %%
[df.columns, df.index]
# Out:
# [Index(['dataset', 'x', 'y'], dtype='object'),
#  RangeIndex(start=0, stop=44, step=1)]

# %%
df.groupby('dataset')[['x']].transform(sum).head(10)
# Out:
#       x
# 0  99.0
# 1  99.0
# 2  99.0
# 3  99.0
# 4  99.0
# 5  99.0
# 6  99.0
# 7  99.0
# 8  99.0
# 9  99.0

# %%
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
df.describe().T
# Out:
#    count      mean       std  min     25%   50%      75%    max
# x   44.0  9.000000  3.198837  4.0  7.0000  8.00  11.0000  19.00
# y   44.0  7.500682  1.958925  3.1  6.1175  7.52   8.7475  12.74

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
kat_df = df.select_dtypes(include=['object'])
kat_df.head()
# Out:
#   dataset
# 0       I
# 1       I
# 2       I
# 3       I
# 4       I

# %%
kat_df.dataset.unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
kat_df['dataset'].value_counts().count()
# Out:
# 4

# %%
kat_df['dataset'].value_counts()
# Out:
# I      11
# II     11
# III    11
# IV     11
# Name: dataset, dtype: int64

# %%
df['dataset'].value_counts().plot.barh();

# %%
#--------------------------------------------------------------------------------------------------------------

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('attention')
df = df.copy()
df.head()
# Out:
#    Unnamed: 0  subject attention  solutions  score
# 0           0        1   divided          1    2.0
# 1           1        2   divided          1    3.0
# 2           2        3   divided          1    3.0
# 3           3        4   divided          1    5.0
# 4           4        5   divided          1    4.0

# %%
df.describe().T
# Out:
#             count       mean        std  min    25%   50%    75%   max
# Unnamed: 0   60.0  29.500000  17.464249  0.0  14.75  29.5  44.25  59.0
# subject      60.0  10.500000   5.814943  1.0   5.75  10.5  15.25  20.0
# solutions    60.0   2.000000   0.823387  1.0   1.00   2.0   3.00   3.0
# score        60.0   5.958333   1.621601  2.0   5.00   6.0   7.00   9.0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'subject', 'attention', 'solutions', 'score'], dtype='object')

# %%
df.groupby('attention')[['score']].transform(sum).head()
# Out:
#    score
# 0  153.5
# 1  153.5
# 2  153.5
# 3  153.5
# 4  153.5

# %%
kat_df = df.select_dtypes(include=['object'])
kat_df.head()
# Out:
#   attention
# 0   divided
# 1   divided
# 2   divided
# 3   divided
# 4   divided

# %%
kat_df.attention.unique()
# Out:
# array(['divided', 'focused'], dtype=object)

# %%
kat_df['attention'].value_counts().count()
# Out:
# 2

# %%
kat_df['attention'].value_counts()
# Out:
# divided    30
# focused    30
# Name: attention, dtype: int64

# %%
kat_df['attention'].value_counts().plot.barh();
